# %%
import matplotlib.pyplot as plt
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from keras.layers import Dense,Flatten, Dropout
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

train = ImageDataGenerator(rescale = 1./255,
                           width_shift_range=0.1,
                           rotation_range=20,
                           height_shift_range=0.1,
                           zoom_range=0.2,
                           brightness_range=(0.5,1.5),
                           horizontal_flip=True,
                           vertical_flip=True)
validation = ImageDataGenerator(rescale = 1./255)

train_data = train.flow_from_directory('/content/drive/MyDrive/AI/VietnamMoney/Training',
                                       target_size = (100,100),
                                       class_mode = 'categorical',
                                       shuffle = True)
validation_dataset = train.flow_from_directory('/content/drive/MyDrive/AI/VietnamMoney/Validation',
                                       target_size = (100,100),
                                       class_mode = 'categorical',
                                       shuffle = True)

model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same',input_shape=(100,100,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.5))
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.3))
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))

model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(train_data,epochs=30,batch_size=128,validation_data=validation_dataset,verbose=1)
# Out:
# Found 859 images belonging to 11 classes.
# Found 83 images belonging to 11 classes.
# Epoch 1/30
# 27/27 [==============================] - 73s 3s/step - loss: 4.1338 - accuracy: 0.0955 - val_loss: 2.3989 - val_accuracy: 0.1446
# Epoch 2/30
# 27/27 [==============================] - 69s 3s/step - loss: 2.3190 - accuracy: 0.1607 - val_loss: 2.2978 - val_accuracy: 0.1205
# Epoch 3/30
# 27/27 [==============================] - 69s 3s/step - loss: 2.2263 - accuracy: 0.1956 - val_loss: 2.1609 - val_accuracy: 0.2651
# Epoch 4/30
# 27/27 [==============================] - 69s 3s/step - loss: 2.1223 - accuracy: 0.2561 - val_loss: 2.2206 - val_accuracy: 0.2410
# Epoch 5/30
# 27/27 [==============================] - 69s 3s/step - loss: 2.0893 - accuracy: 0.2608 - val_loss: 2.1200 - val_accuracy: 0.2771
# Epoch 6/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.9779 - accuracy: 0.3190 - val_loss: 2.2941 - val_accuracy: 0.2289
# Epoch 7/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.9453 - accuracy: 0.3271 - val_loss: 2.1141 - val_accuracy: 0.3012
# Epoch 8/30
# 27/27 [==============================] - 68s 3s/step - loss: 1.9284 - accuracy: 0.3271 - val_loss: 2.1225 - val_accuracy: 0.2892
# Epoch 9/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.9262 - accuracy: 0.3295 - val_loss: 2.2758 - val_accuracy: 0.1807
# Epoch 10/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.8438 - accuracy: 0.3399 - val_loss: 2.1675 - val_accuracy: 0.3253
# Epoch 11/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.7822 - accuracy: 0.4005 - val_loss: 2.3099 - val_accuracy: 0.2892
# Epoch 12/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.6884 - accuracy: 0.4214 - val_loss: 2.1900 - val_accuracy: 0.3735
# Epoch 13/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.5950 - accuracy: 0.4715 - val_loss: 2.1031 - val_accuracy: 0.4217
# Epoch 14/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.5526 - accuracy: 0.4901 - val_loss: 2.1614 - val_accuracy: 0.3735
# Epoch 15/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.4831 - accuracy: 0.4854 - val_loss: 2.0431 - val_accuracy: 0.4578
# Epoch 16/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.4751 - accuracy: 0.4913 - val_loss: 2.1090 - val_accuracy: 0.4458
# Epoch 17/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.4909 - accuracy: 0.4948 - val_loss: 1.9119 - val_accuracy: 0.4578
# Epoch 18/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.3327 - accuracy: 0.5460 - val_loss: 2.3451 - val_accuracy: 0.4578
# Epoch 19/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.3323 - accuracy: 0.5367 - val_loss: 2.2833 - val_accuracy: 0.4940
# Epoch 20/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.2222 - accuracy: 0.5856 - val_loss: 2.3167 - val_accuracy: 0.3735
# Epoch 21/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.2902 - accuracy: 0.5693 - val_loss: 2.3017 - val_accuracy: 0.5542
# Epoch 22/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.1700 - accuracy: 0.5949 - val_loss: 2.3095 - val_accuracy: 0.5422
# Epoch 23/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.1147 - accuracy: 0.6088 - val_loss: 2.5208 - val_accuracy: 0.4578
# Epoch 24/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.0834 - accuracy: 0.6054 - val_loss: 2.2243 - val_accuracy: 0.4578
# Epoch 25/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.0675 - accuracy: 0.6496 - val_loss: 2.6583 - val_accuracy: 0.5060
# Epoch 26/30
# 27/27 [==============================] - 68s 3s/step - loss: 0.9938 - accuracy: 0.6694 - val_loss: 2.6887 - val_accuracy: 0.5663
# Epoch 27/30
# 27/27 [==============================] - 69s 3s/step - loss: 0.9662 - accuracy: 0.6671 - val_loss: 2.8271 - val_accuracy: 0.4337
# Epoch 28/30
# 27/27 [==============================] - 69s 3s/step - loss: 1.0314 - accuracy: 0.6705 - val_loss: 2.4474 - val_accuracy: 0.4940
# Epoch 29/30
# 27/27 [==============================] - 69s 3s/step - loss: 0.9408 - accuracy: 0.6729 - val_loss: 2.3634 - val_accuracy: 0.5422
# Epoch 30/30
# 27/27 [==============================] - 74s 3s/step - loss: 0.9557 - accuracy: 0.6740 - val_loss: 2.3971 - val_accuracy: 0.5904

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 150, 150, 32)      896
#
#  max_pooling2d_26 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 75, 75, 32)        9248
#
#  max_pooling2d_27 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 43808)             0
#
#  dense_27 (Dense)            (None, 128)               5607552
#
#  dense_28 (Dense)            (None, 11)                1419
#
# =================================================================
# Total params: 5,619,115
# Trainable params: 5,619,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('độ chính xác kiểm tra là: ',score[1])
# Out:
# Sai số kiểm tra là:  2.512387275695801
# độ chính xác kiểm tra là:  0.5783132314682007

# %%
train_data.class_indices
# Out:
# {'100K': 0,
#  '10K': 1,
#  '1K': 2,
#  '200K': 3,
#  '200d': 4,
#  '20K': 5,
#  '2K': 6,
#  '500K': 7,
#  '500d': 8,
#  '50K': 9,
#  '5K': 10}

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('accuracy of VN Monney Classification use CNN')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upper left')
plt.show()

# %%
model.save('/content/drive/MyDrive/AI/VN_Monney_Classification_CNN.h5')

# %%
from tensorflow import keras
model = keras.models.load_model('/content/drive/MyDrive/AI/VN_Monney_Classification_CNN.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
names = ['100K','10K','1K','200K','200Đ','20K','2K','500K','500Đ','50K','5K']
dir = '/content/drive/MyDrive/AI/VietnamMoney/Test'
plt.figure(figsize=(10,10))
for i in range(18):
  plt.subplot(3,6,i + 1)
  img = load_img(dir +'/'+ str(i)+'.jpg', target_size=(100,100))
  plt.imshow(img)
  img = img_to_array(img)
  img = img.reshape(1,100,100,3)
  image = img/255.0
  plt.xticks([])
  plt.yticks([])
  plt.title(names[np.argmax(model.predict(image))])
